# %%
from string import ascii_letters
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Oscars.csv')

# %%
df['Oscar_Best_Picture_won'] = df['Oscar_Best_Picture_won'].astype('category')
df['Oscar_Best_Picture_won'] = df['Oscar_Best_Picture_won'].cat.codes
df['Oscar_Best_Director_won'] = df['Oscar_Best_Director_won'].astype('category')
df['Oscar_Best_Director_won'] = df['Oscar_Best_Director_won'].cat.codes

# %%
AllColumns=[]
for i in df:
    AllColumns.append(i)
AllOutliers=[]
for i in range(len(AllColumns)):
    _, bp = pd.DataFrame.boxplot(AllColumns[i], return_type='both')
    
    outliers = [flier.get_ydata() for flier in bp["fliers"]]
    AllOutliers.append(outliers[0])
    
print(len(AllOutliers)).len(AllColumns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-9d0686ca7522> in <module>
#       4 AllOutliers=[]
#       5 for i in range(len(AllColumns)):
# ----> 6     _, bp = pd.DataFrame.boxplot(AllColumns[i], return_type='both')
#       7
#       8     outliers = [flier.get_ydata() for flier in bp["fliers"]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     445         layout=layout,
#     446         return_type=return_type,
# --> 447         **kwargs,
#     448     )
#     449
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     373         layout=layout,
#     374         return_type=return_type,
# ...

# %%
col1.corr(col2)
# Out:
# 0.9510025105026894

# %%
for column in list(df.columns):
    if(df[column].dtype.name=='object'):
        df[column] = df[column].astype('category')
        df[column] = df[column].cat.codes

# %%
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop
def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

# %%
get_top_abs_correlations(df, 119*119+1)
# Out:
# release_date                                 release_date.year                                          0.997876
# year                                         release_date.year                                          0.996320
# Hollywood_Film_won                           Hollywood_Film_nominated                                   0.994032
# Hollywood_Film_won_categories                Hollywood_Film_nominated_categories                        0.991547
# Directors_Guild_won                          Directors_Guild_won_categories                             0.961488
#                                                                                                           ...
# New_York_Film_Critics_Circle_won_categories  release_date.day-of-week                                   0.000154
# Directors_Guild_nominated_categories         People_Choice_won_categories                               0.000082
# ...

# %%
df
# Out:
#       year  movie  movie_id  certificate  duration  genre  rate  metascore  \
# 0     2001    468         0            3       118    129   6.4       44.0
# 1     2000    185         1            0        84     80   7.0       88.0
# 2     2005    285         2            3       106      5   5.7       40.0
# 3     2002    311         3            4       123    101   7.4       61.0
# 4     2001    956         4            3       178     63   8.8       92.0
# ...    ...    ...       ...          ...       ...    ...   ...        ...
# 1178  2017    164      1178            4       132    191   8.3       93.0
# 1179  2017    642      1179            4       130    191   8.4       90.0
# 1180  2017   1120      1180            3       111     98   6.8       58.0
# 1181  2017    697      1181            3       122    140   6.3       58.0
# 1182  2017    994      1182            3       116     98   7.4       83.0
#
# ...
