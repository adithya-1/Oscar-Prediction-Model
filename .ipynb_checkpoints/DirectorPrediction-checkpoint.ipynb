# %%
#Prediciton model for Best Director
# importing required libraries
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Data For Prediction.csv")

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
train=df.drop(
    [
   #'year',
  'certificate',
    #'movie',
        
                                                        # used to drop the columns not required i.e not important attributes 
                                                        # by not commenting the perticular attribute,
                                                        # initially all the attributes will be commented in order to get list of
                                                        # important attributes
                                                        

    'genre', 
  # 'rate',
    'metascore', 
     #'votes',
     'gross', 
     'user_reviews',
     'critic_reviews',
     'popularity', 
     #'awards_wins',
     'awards_nominations',
 'Oscar_Best_Picture_won',
#'Oscar_Best_Picture_nominated', 
    'Oscar_Best_Director_won',
      
   #'Oscar_Best_Director_nominated',
    'Oscar_Best_Actor_won',
    #'Oscar_Best_Actor_nominated', 
    'Oscar_Best_Actress_won',
   #'Oscar_Best_Actress_nominated',
   'other_bestPicture_won',
     #'other_director_won', 
    #'other_actor_won', 
   'other_actress_won',
    'other_bestPicture_nominated', 
     'other_director_nominated',
       'other_actor_nominated',
    'other_actress_nominated'
    ],
     
     
     
     
     
    axis=1)

# %%
test=pd.DataFrame() #initialising empty test dataframe

# %%
test['Oscar_Best_Director_won']=df['Oscar_Best_Director_won'] # adding the output label to test the data

# %%
X_train=[]
Y_train=[]
X_test=[]
Y_test=[]
for i in train.index:
    if(int(train['year'][i])<2017):                              #splitting the test data based on year 
                                                                 #train -from 2001-2016
                                                                 #test -2017
        print(train.iloc[i])
        X_train.append(train.iloc[i])
        Y_train.append(test['Oscar_Best_Director_won'][i])
    else:
        X_test.append(train.iloc[i])
        Y_test.append(test['Oscar_Best_Director_won'][i])
# Out:
# year                                       2001
# movie                            Kate & Leopold
# rate                                        6.4
# votes                                     66660
# awards_wins                                   1
# Oscar_Best_Picture_nominated                  0
# Oscar_Best_Director_nominated                 0
# Oscar_Best_Actor_nominated                    0
# Oscar_Best_Actress_nominated                  0
# other_director_won                            0
# other_actor_won                               0
# Name: 0, dtype: object
# year                                    2000
# movie                            Chicken Run
# rate                                       7
# votes                                 144475
# awards_wins                                5
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# Oscar_Best_Actor_nominated                 0
# Oscar_Best_Actress_nominated               0
# other_director_won                         0
# other_actor_won                            0
# Name: 1, dtype: object
# year                                       2005
# movie                            Fantastic Four
# rate                                        5.7
# votes                                    273203
# awards_wins                                   0
# Oscar_Best_Picture_nominated                  0
# Oscar_Best_Director_nominated                 0
# Oscar_Best_Actor_nominated                    0
# Oscar_Best_Actress_nominated                  0
# other_director_won                            0
# other_actor_won                               0
# Name: 2, dtype: object
# year                              2002
# movie                            Frida
# rate                               7.4
# votes                            63852
# awards_wins                          2
# Oscar_Best_Picture_nominated         0
# Oscar_Best_Director_nominated        0
# Oscar_Best_Actor_nominated           0
# Oscar_Best_Actress_nominated         1
# other_director_won                   0
# other_actor_won                      0
# Name: 3, dtype: object
# year                                                                          2001
# movie                            The Lord of the Rings: The Fellowship of the Ring
# rate                                                                           8.8
# votes                                                                      1286275
# awards_wins                                                                     26
# Oscar_Best_Picture_nominated                                                     1
# Oscar_Best_Director_nominated                                                    1
# Oscar_Best_Actor_nominated                                                       0
# Oscar_Best_Actress_nominated                                                     0
# other_director_won                                                               1
# other_actor_won                                                                  0
# Name: 4, dtype: object
# year                                               2000
# movie                            Mission: Impossible II
# rate                                                6.1
# votes                                            249988
# awards_wins                                           1
# Oscar_Best_Picture_nominated                          0
# Oscar_Best_Director_nominated                         0
# Oscar_Best_Actor_nominated                            0
# Oscar_Best_Actress_nominated                          0
# other_director_won                                    0
# other_actor_won                                       0
# Name: 5, dtype: object
# year                                      2002
# movie                            Resident Evil
# rate                                       6.7
# votes                                   204545
# awards_wins                                  0
# Oscar_Best_Picture_nominated                 0
# Oscar_Best_Director_nominated                0
# Oscar_Best_Actor_nominated                   0
# Oscar_Best_Actress_nominated                 0
# other_director_won                           0
# other_actor_won                              0
# Name: 6, dtype: object
# year                               2000
# movie                             X-Men
# rate                                7.4
# votes                            468351
# awards_wins                           0
# Oscar_Best_Picture_nominated          0
# Oscar_Best_Director_nominated         0
# Oscar_Best_Actor_nominated            0
# Oscar_Best_Actress_nominated          0
# other_director_won                    0
# other_actor_won                       0
# Name: 7, dtype: object
# year                                                 2000
# movie                            The Emperor's New Groove
# rate                                                  7.3
# votes                                              133781
# awards_wins                                             2
# Oscar_Best_Picture_nominated                            0
# Oscar_Best_Director_nominated                           0
# Oscar_Best_Actor_nominated                              0
# Oscar_Best_Actress_nominated                            0
# other_director_won                                      0
# other_actor_won                                         0
# Name: 8, dtype: object
# year                                     2005
# movie                            Corpse Bride
# rate                                      7.4
# votes                                  197604
# awards_wins                                 0
# Oscar_Best_Picture_nominated                0
# Oscar_Best_Director_nominated               0
# Oscar_Best_Actor_nominated                  0
# Oscar_Best_Actress_nominated                0
# other_director_won                          0
# other_actor_won                             0
# Name: 9, dtype: object
# year                                                                     2002
# movie                            Star Wars: Episode II - Attack of the Clones
# rate                                                                      6.7
# votes                                                                  485730
# awards_wins                                                                 0
# Oscar_Best_Picture_nominated                                                0
# Oscar_Best_Director_nominated                                               0
# Oscar_Best_Actor_nominated                                                  0
# Oscar_Best_Actress_nominated                                                0
# other_director_won                                                          0
# other_actor_won                                                             0
# Name: 10, dtype: object
# year                                                                     2005
# movie                            Star Wars: Episode III - Revenge of the Sith
# rate                                                                      7.6
# votes                                                                  543318
# awards_wins                                                                 2
# Oscar_Best_Picture_nominated                                                0
# Oscar_Best_Director_nominated                                               0
# Oscar_Best_Actor_nominated                                                  0
# Oscar_Best_Actress_nominated                                                0
# other_director_won                                                          0
# other_actor_won                                                             0
# Name: 11, dtype: object
# year                               2001
# movie                             Shrek
# rate                                7.9
# votes                            483447
# awards_wins                           9
# Oscar_Best_Picture_nominated          0
# Oscar_Best_Director_nominated         0
# Oscar_Best_Actor_nominated            0
# Oscar_Best_Actress_nominated          0
# other_director_won                    0
# other_actor_won                       0
# Name: 12, dtype: object
# year                                           2001
# movie                            Planet of the Apes
# rate                                            5.7
# votes                                        181213
# awards_wins                                       0
# Oscar_Best_Picture_nominated                      0
# Oscar_Best_Director_nominated                     0
# Oscar_Best_Actor_nominated                        0
# Oscar_Best_Actress_nominated                      0
# other_director_won                                0
# other_actor_won                                   0
# Name: 13, dtype: object
# year                                        2002
# movie                            Treasure Planet
# rate                                         7.1
# votes                                      74746
# awards_wins                                    0
# Oscar_Best_Picture_nominated                   0
# Oscar_Best_Director_nominated                  0
# Oscar_Best_Actor_nominated                     0
# Oscar_Best_Actress_nominated                   0
# other_director_won                             0
# other_actor_won                                0
# Name: 14, dtype: object
# year                                    2000
# movie                            Pitch Black
# rate                                     7.1
# votes                                 197982
# awards_wins                                0
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# Oscar_Best_Actor_nominated                 0
# Oscar_Best_Actress_nominated               0
# other_director_won                         0
# other_actor_won                            0
# Name: 15, dtype: object
# year                                     2001
# movie                            Training Day
# rate                                      7.7
# votes                                  316040
# awards_wins                                 2
# Oscar_Best_Picture_nominated                0
# Oscar_Best_Director_nominated               0
# Oscar_Best_Actor_nominated                  1
# Oscar_Best_Actress_nominated                0
# other_director_won                          0
# other_actor_won                             2
# Name: 16, dtype: object
# year                              2000
# movie                            U-571
# rate                               6.6
# votes                            66965
# awards_wins                          0
# Oscar_Best_Picture_nominated         0
# Oscar_Best_Director_nominated        0
# Oscar_Best_Actor_nominated           0
# Oscar_Best_Actress_nominated         0
# other_director_won                   0
# other_actor_won                      0
# Name: 17, dtype: object
# year                                        2000
# movie                            American Psycho
# rate                                         7.6
# votes                                     371133
# awards_wins                                    0
# Oscar_Best_Picture_nominated                   0
# Oscar_Best_Director_nominated                  0
# Oscar_Best_Actor_nominated                     0
# Oscar_Best_Actress_nominated                   0
# other_director_won                             0
# other_actor_won                                0
# Name: 18, dtype: object
# year                                   2002
# movie                            Spider-Man
# rate                                    7.3
# votes                                561251
# awards_wins                               1
# Oscar_Best_Picture_nominated              0
# Oscar_Best_Director_nominated             0
# Oscar_Best_Actor_nominated                0
# Oscar_Best_Actress_nominated              0
# other_director_won                        0
# other_actor_won                           0
# Name: 19, dtype: object
# year                                                2001
# movie                            Lara Croft: Tomb Raider
# rate                                                 5.7
# votes                                             161278
# awards_wins                                            0
# Oscar_Best_Picture_nominated                           0
# Oscar_Best_Director_nominated                          0
# Oscar_Best_Actor_nominated                             0
# Oscar_Best_Actress_nominated                           0
# other_director_won                                     0
# other_actor_won                                        0
# Name: 20, dtype: object
# year                                      2000
# movie                            High Fidelity
# rate                                       7.5
# votes                                   146486
# awards_wins                                  0
# Oscar_Best_Picture_nominated                 0
# Oscar_Best_Director_nominated                0
# Oscar_Best_Actor_nominated                   0
# Oscar_Best_Actress_nominated                 0
# other_director_won                           0
# other_actor_won                              0
# Name: 21, dtype: object
# year                                                           2000
# movie                            The Flintstones in Viva Rock Vegas
# rate                                                            3.6
# votes                                                         16035
# awards_wins                                                       0
# Oscar_Best_Picture_nominated                                      0
# Oscar_Best_Director_nominated                                     0
# Oscar_Best_Actor_nominated                                        0
# Oscar_Best_Actress_nominated                                      0
# other_director_won                                                0
# other_actor_won                                                   0
# Name: 22, dtype: object
# year                                      2003
# movie                            Cold Mountain
# rate                                       7.2
# votes                                   120878
# awards_wins                                  5
# Oscar_Best_Picture_nominated                 0
# Oscar_Best_Director_nominated                0
# Oscar_Best_Actor_nominated                   1
# Oscar_Best_Actress_nominated                 0
# other_director_won                           0
# other_actor_won                              0
# Name: 23, dtype: object
# year                                         2000
# movie                            Charlie's Angels
# rate                                          5.5
# votes                                      148354
# awards_wins                                     0
# Oscar_Best_Picture_nominated                    0
# Oscar_Best_Director_nominated                   0
# Oscar_Best_Actor_nominated                      0
# Oscar_Best_Actress_nominated                    0
# other_director_won                              0
# other_actor_won                                 0
# Name: 24, dtype: object
# year                                          2001
# movie                            Nowhere in Africa
# rate                                           7.7
# votes                                        10887
# awards_wins                                      0
# Oscar_Best_Picture_nominated                     0
# Oscar_Best_Director_nominated                    0
# Oscar_Best_Actor_nominated                       0
# Oscar_Best_Actress_nominated                     0
# other_director_won                               0
# other_actor_won                                  0
# Name: 25, dtype: object
# year                                  2000
# movie                            Cast Away
# rate                                   7.7
# votes                               409544
# awards_wins                              6
# Oscar_Best_Picture_nominated             0
# Oscar_Best_Director_nominated            0
# Oscar_Best_Actor_nominated               1
# Oscar_Best_Actress_nominated             0
# other_director_won                       0
# other_actor_won                          3
# Name: 26, dtype: object
# year                                    2001
# movie                            Ghost World
# rate                                     7.4
# votes                                  98471
# awards_wins                                4
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# Oscar_Best_Actor_nominated                 0
# Oscar_Best_Actress_nominated               0
# other_director_won                         0
# other_actor_won                            0
# Name: 27, dtype: object
# year                                          2001
# movie                            Jurassic Park III
# rate                                           5.9
# votes                                       227486
# awards_wins                                      0
# Oscar_Best_Picture_nominated                     0
# Oscar_Best_Director_nominated                    0
# Oscar_Best_Actor_nominated                       0
# Oscar_Best_Actress_nominated                     0
# other_director_won                               0
# other_actor_won                                  0
# Name: 28, dtype: object
# year                                  2000
# movie                            The Beach
# rate                                   6.6
# votes                               182324
# awards_wins                              0
# Oscar_Best_Picture_nominated             0
# Oscar_Best_Director_nominated            0
# Oscar_Best_Actor_nominated               0
# Oscar_Best_Actress_nominated             0
# other_director_won                       0
# other_actor_won                          0
# Name: 29, dtype: object
# year                                   2000
# movie                            Hollow Man
# rate                                    5.7
# votes                                104404
# awards_wins                               0
# Oscar_Best_Picture_nominated              0
# Oscar_Best_Director_nominated             0
# Oscar_Best_Actor_nominated                0
# Oscar_Best_Actress_nominated              0
# other_director_won                        0
# other_actor_won                           0
# Name: 30, dtype: object
# year                                             2002
# movie                            The Sum of All Fears
# rate                                              6.4
# votes                                           88382
# awards_wins                                         0
# Oscar_Best_Picture_nominated                        0
# Oscar_Best_Director_nominated                       0
# Oscar_Best_Actor_nominated                          0
# Oscar_Best_Actress_nominated                        0
# other_director_won                                  0
# other_actor_won                                     0
# Name: 31, dtype: object
# year                                            2001
# movie                            Along Came a Spider
# rate                                             6.3
# votes                                          60579
# awards_wins                                        0
# Oscar_Best_Picture_nominated                       0
# Oscar_Best_Director_nominated                      0
# Oscar_Best_Actor_nominated                         0
# Oscar_Best_Actress_nominated                       0
# other_director_won                                 0
# other_actor_won                                    0
# Name: 32, dtype: object
# year                                       2000
# movie                            Romeo Must Die
# rate                                        6.1
# votes                                     58111
# awards_wins                                   0
# Oscar_Best_Picture_nominated                  0
# Oscar_Best_Director_nominated                 0
# Oscar_Best_Actor_nominated                    0
# Oscar_Best_Actress_nominated                  0
# other_director_won                            0
# other_actor_won                               0
# Name: 33, dtype: object
# year                                                         2002
# movie                            Spirit: Stallion of the Cimarron
# rate                                                          7.1
# votes                                                       46943
# awards_wins                                                     0
# Oscar_Best_Picture_nominated                                    0
# Oscar_Best_Director_nominated                                   0
# Oscar_Best_Actor_nominated                                      0
# Oscar_Best_Actress_nominated                                    0
# other_director_won                                              0
# other_actor_won                                                 0
# Name: 34, dtype: object
# year                                         2001
# movie                            Mulholland Drive
# rate                                            8
# votes                                      247207
# awards_wins                                    11
# Oscar_Best_Picture_nominated                    0
# Oscar_Best_Director_nominated                   1
# Oscar_Best_Actor_nominated                      0
# Oscar_Best_Actress_nominated                    0
# other_director_won                              3
# other_actor_won                                 0
# Name: 35, dtype: object
# year                                2004
# movie                            Hellboy
# rate                                 6.8
# votes                             250754
# awards_wins                            0
# Oscar_Best_Picture_nominated           0
# Oscar_Best_Director_nominated          0
# Oscar_Best_Actor_nominated             0
# Oscar_Best_Actress_nominated           0
# other_director_won                     0
# other_actor_won                        0
# Name: 36, dtype: object
# year                                                                      2003
# movie                            The Lord of the Rings: The Return of the King
# rate                                                                       8.9
# votes                                                                  1264277
# awards_wins                                                                 48
# Oscar_Best_Picture_nominated                                                 1
# Oscar_Best_Director_nominated                                                1
# Oscar_Best_Actor_nominated                                                   0
# Oscar_Best_Actress_nominated                                                 0
# other_director_won                                                           8
# other_actor_won                                                              0
# Name: 37, dtype: object
# year                                                              2002
# movie                            The Lord of the Rings: The Two Towers
# rate                                                               8.7
# votes                                                          1145458
# awards_wins                                                         25
# Oscar_Best_Picture_nominated                                         1
# Oscar_Best_Director_nominated                                        0
# Oscar_Best_Actor_nominated                                           0
# Oscar_Best_Actress_nominated                                         0
# other_director_won                                                   2
# other_actor_won                                                      0
# Name: 38, dtype: object
# year                                           2000
# movie                            Dancer in the Dark
# rate                                              8
# votes                                         82205
# awards_wins                                       3
# Oscar_Best_Picture_nominated                      0
# Oscar_Best_Director_nominated                     0
# Oscar_Best_Actor_nominated                        0
# Oscar_Best_Actress_nominated                      0
# other_director_won                                0
# other_actor_won                                   0
# Name: 39, dtype: object
# year                                                          2001
# movie                            Lagaan: Once Upon a Time in India
# rate                                                           8.2
# votes                                                        77479
# awards_wins                                                      0
# Oscar_Best_Picture_nominated                                     0
# Oscar_Best_Director_nominated                                    0
# Oscar_Best_Actor_nominated                                       0
# Oscar_Best_Actress_nominated                                     0
# other_director_won                                               0
# other_actor_won                                                  0
# Name: 40, dtype: object
# year                                                       2000
# movie                            How the Grinch Stole Christmas
# rate                                                          6
# votes                                                    150313
# awards_wins                                                   2
# Oscar_Best_Picture_nominated                                  0
# Oscar_Best_Director_nominated                                 0
# Oscar_Best_Actor_nominated                                    0
# Oscar_Best_Actress_nominated                                  0
# other_director_won                                            0
# other_actor_won                                               0
# Name: 41, dtype: object
# year                                    2003
# movie                            Bad Boys II
# rate                                     6.6
# votes                                 183145
# awards_wins                                0
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# Oscar_Best_Actor_nominated                 0
# Oscar_Best_Actress_nominated               0
# other_director_won                         0
# other_actor_won                            0
# Name: 42, dtype: object
# year                                  2000
# movie                            Gladiator
# rate                                   8.5
# votes                              1024040
# awards_wins                             18
# Oscar_Best_Picture_nominated             1
# Oscar_Best_Director_nominated            1
# Oscar_Best_Actor_nominated               1
# Oscar_Best_Actress_nominated             0
# other_director_won                       0
# other_actor_won                          2
# Name: 43, dtype: object
# year                                    2000
# movie                            Scary Movie
# rate                                     6.2
# votes                                 192128
# awards_wins                                0
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# Oscar_Best_Actor_nominated                 0
# Oscar_Best_Actress_nominated               0
# other_director_won                         0
# other_actor_won                            0
# Name: 44, dtype: object
# year                                          2000
# movie                            The Perfect Storm
# rate                                           6.4
# votes                                       135888
# awards_wins                                      1
# Oscar_Best_Picture_nominated                     0
# Oscar_Best_Director_nominated                    0
# Oscar_Best_Actor_nominated                       0
# Oscar_Best_Actress_nominated                     0
# other_director_won                               0
# other_actor_won                                  0
# Name: 45, dtype: object
# year                               2000
# movie                            Quills
# rate                                7.4
# votes                             45631
# awards_wins                           3
# Oscar_Best_Picture_nominated          0
# Oscar_Best_Director_nominated         0
# Oscar_Best_Actor_nominated            1
# Oscar_Best_Actress_nominated          0
# other_director_won                    0
# other_actor_won                       0
# Name: 46, dtype: object
# year                                            2000
# movie                            Requiem for a Dream
# rate                                             8.4
# votes                                         596759
# awards_wins                                        9
# Oscar_Best_Picture_nominated                       0
# Oscar_Best_Director_nominated                      0
# Oscar_Best_Actor_nominated                         0
# Oscar_Best_Actress_nominated                       1
# other_director_won                                 1
# other_actor_won                                    0
# Name: 47, dtype: object
# year                                        2002
# movie                            Minority Report
# rate                                         7.7
# votes                                     413070
# awards_wins                                    4
# Oscar_Best_Picture_nominated                   0
# Oscar_Best_Director_nominated                  0
# Oscar_Best_Actor_nominated                     0
# Oscar_Best_Actress_nominated                   0
# other_director_won                             1
# other_actor_won                                0
# Name: 48, dtype: object
# year                                                           2003
# movie                            Terminator 3: Rise of the Machines
# rate                                                            6.4
# votes                                                        313931
# awards_wins                                                       0
# Oscar_Best_Picture_nominated                                      0
# Oscar_Best_Director_nominated                                     0
# Oscar_Best_Actor_nominated                                        0
# Oscar_Best_Actress_nominated                                      0
# other_director_won                                                0
# other_actor_won                                                   0
# Name: 49, dtype: object
# year                                2000
# movie                            Traffic
# rate                                 7.6
# votes                             173632
# awards_wins                           18
# Oscar_Best_Picture_nominated           1
# Oscar_Best_Director_nominated          1
# Oscar_Best_Actor_nominated             0
# Oscar_Best_Actress_nominated           0
# other_director_won                     3
# other_actor_won                        0
# Name: 50, dtype: object
# year                                      2000
# movie                            Almost Famous
# rate                                       7.9
# votes                                   212643
# awards_wins                                 22
# Oscar_Best_Picture_nominated                 0
# Oscar_Best_Director_nominated                0
# Oscar_Best_Actor_nominated                   0
# Oscar_Best_Actress_nominated                 0
# other_director_won                           1
# other_actor_won                              0
# Name: 51, dtype: object
# year                                    2000
# movie                            Boiler Room
# rate                                       7
# votes                                  42344
# awards_wins                                0
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# Oscar_Best_Actor_nominated                 0
# Oscar_Best_Actress_nominated               0
# other_director_won                         0
# other_actor_won                            0
# Name: 52, dtype: object
# year                                           2000
# movie                            Me, Myself & Irene
# rate                                            6.5
# votes                                        190379
# awards_wins                                       0
# Oscar_Best_Picture_nominated                      0
# Oscar_Best_Director_nominated                     0
# Oscar_Best_Actor_nominated                        0
# Oscar_Best_Actress_nominated                      0
# other_director_won                                0
# other_actor_won                                   0
# Name: 53, dtype: object
# year                                2000
# movie                            Pollock
# rate                                   7
# votes                              23585
# awards_wins                            1
# Oscar_Best_Picture_nominated           0
# Oscar_Best_Director_nominated          0
# Oscar_Best_Actor_nominated             1
# Oscar_Best_Actress_nominated           0
# other_director_won                     0
# other_actor_won                        0
# Name: 54, dtype: object
# year                                        2001
# movie                            A Knight's Tale
# rate                                         6.9
# votes                                     140668
# awards_wins                                    1
# Oscar_Best_Picture_nominated                   0
# Oscar_Best_Director_nominated                  0
# Oscar_Best_Actor_nominated                     0
# Oscar_Best_Actress_nominated                   0
# other_director_won                             0
# other_actor_won                                0
# Name: 55, dtype: object
# year                                    2000
# movie                            Wonder Boys
# rate                                     7.4
# votes                                  55707
# awards_wins                                9
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# Oscar_Best_Actor_nominated                 0
# Oscar_Best_Actress_nominated               0
# other_director_won                         0
# other_actor_won                            1
# Name: 56, dtype: object
# year                                          2000
# movie                            Battlefield Earth
# rate                                           2.4
# votes                                        66552
# awards_wins                                      0
# Oscar_Best_Picture_nominated                     0
# Oscar_Best_Director_nominated                    0
# Oscar_Best_Actor_nominated                       0
# Oscar_Best_Actress_nominated                     0
# other_director_won                               0
# other_actor_won                                  0
# Name: 57, dtype: object
# year                                     2000
# movie                            Little Nicky
# rate                                      5.3
# votes                                   82544
# awards_wins                                 0
# Oscar_Best_Picture_nominated                0
# Oscar_Best_Director_nominated               0
# Oscar_Best_Actor_nominated                  0
# Oscar_Best_Actress_nominated                0
# other_director_won                          0
# other_actor_won                             0
# Name: 58, dtype: object
# year                                  2000
# movie                            Frequency
# rate                                   7.4
# votes                                84574
# awards_wins                              0
# Oscar_Best_Picture_nominated             0
# Oscar_Best_Director_nominated            0
# Oscar_Best_Actor_nominated               0
# Oscar_Best_Actress_nominated             0
# other_director_won                       0
# other_actor_won                          0
# Name: 59, dtype: object
# year                                      2000
# movie                            Space Cowboys
# rate                                       6.4
# votes                                    61837
# awards_wins                                  0
# Oscar_Best_Picture_nominated                 0
# Oscar_Best_Director_nominated                0
# Oscar_Best_Actor_nominated                   0
# Oscar_Best_Actress_nominated                 0
# other_director_won                           0
# other_actor_won                              0
# Name: 60, dtype: object
# year                                              2000
# movie                            Gone in Sixty Seconds
# rate                                               6.5
# votes                                           223486
# awards_wins                                          0
# Oscar_Best_Picture_nominated                         0
# Oscar_Best_Director_nominated                        0
# Oscar_Best_Actor_nominated                           0
# Oscar_Best_Actress_nominated                         0
# other_director_won                                   0
# other_actor_won                                      0
# Name: 61, dtype: object
# year                                    2000
# movie                            The Patriot
# rate                                     7.1
# votes                                 213438
# awards_wins                                0
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# Oscar_Best_Actor_nominated                 0
# Oscar_Best_Actress_nominated               0
# other_director_won                         0
# other_actor_won                            0
# Name: 62, dtype: object
# year                                 2002
# movie                            Blade II
# rate                                  6.7
# votes                              164050
# awards_wins                             0
# Oscar_Best_Picture_nominated            0
# Oscar_Best_Director_nominated           0
# Oscar_Best_Actor_nominated              0
# Oscar_Best_Actress_nominated            0
# other_director_won                      0
# other_actor_won                         0
# Name: 63, dtype: object
# year                                              2000
# movie                            Shadow of the Vampire
# rate                                               6.9
# votes                                            34859
# awards_wins                                          3
# Oscar_Best_Picture_nominated                         0
# Oscar_Best_Director_nominated                        0
# Oscar_Best_Actor_nominated                           0
# Oscar_Best_Actress_nominated                         0
# other_director_won                                   0
# other_actor_won                                      0
# Name: 64, dtype: object
# year                                                       2000
# movie                            Crouching Tiger, Hidden Dragon
# rate                                                        7.9
# votes                                                    221957
# awards_wins                                                  28
# Oscar_Best_Picture_nominated                                  1
# Oscar_Best_Director_nominated                                 1
# Oscar_Best_Actor_nominated                                    0
# Oscar_Best_Actress_nominated                                  0
# other_director_won                                            2
# other_actor_won                                               0
# Name: 65, dtype: object
# year                                                   2000
# movie                            O Brother, Where Art Thou?
# rate                                                    7.8
# votes                                                232646
# awards_wins                                               1
# Oscar_Best_Picture_nominated                              0
# Oscar_Best_Director_nominated                             0
# Oscar_Best_Actor_nominated                                0
# Oscar_Best_Actress_nominated                              0
# other_director_won                                        0
# other_actor_won                                           0
# Name: 66, dtype: object
# year                              2000
# movie                            Vatel
# rate                               6.6
# votes                             6463
# awards_wins                          0
# Oscar_Best_Picture_nominated         0
# Oscar_Best_Director_nominated        0
# Oscar_Best_Actor_nominated           0
# Oscar_Best_Actress_nominated         0
# other_director_won                   0
# other_actor_won                      0
# Name: 67, dtype: object
# year                                       2000
# movie                            Vertical Limit
# rate                                        5.9
# votes                                     50576
# awards_wins                                   0
# Oscar_Best_Picture_nominated                  0
# Oscar_Best_Director_nominated                 0
# Oscar_Best_Actor_nominated                    0
# Oscar_Best_Actress_nominated                  0
# other_director_won                            0
# other_actor_won                               0
# Name: 68, dtype: object
# year                                         2000
# movie                            The Replacements
# rate                                          6.5
# votes                                       49276
# awards_wins                                     0
# Oscar_Best_Picture_nominated                    0
# Oscar_Best_Director_nominated                   0
# Oscar_Best_Actor_nominated                      0
# Oscar_Best_Actress_nominated                    0
# other_director_won                              0
# other_actor_won                                 0
# Name: 69, dtype: object
# year                                        2000
# movie                            Erin Brockovich
# rate                                         7.3
# votes                                     139323
# awards_wins                                   13
# Oscar_Best_Picture_nominated                   1
# Oscar_Best_Director_nominated                  1
# Oscar_Best_Actor_nominated                     0
# Oscar_Best_Actress_nominated                   1
# other_director_won                             3
# other_actor_won                                0
# Name: 70, dtype: object
# year                                          2000
# movie                            Final Destination
# rate                                           6.7
# votes                                       186452
# awards_wins                                      0
# Oscar_Best_Picture_nominated                     0
# Oscar_Best_Director_nominated                    0
# Oscar_Best_Actor_nominated                       0
# Oscar_Best_Actress_nominated                     0
# other_director_won                               0
# other_actor_won                                  0
# Name: 71, dtype: object
# year                                  2001
# movie                            Zoolander
# rate                                   6.6
# votes                               207208
# awards_wins                              0
# Oscar_Best_Picture_nominated             0
# Oscar_Best_Director_nominated            0
# Oscar_Best_Actor_nominated               0
# Oscar_Best_Actress_nominated             0
# other_director_won                       0
# other_actor_won                          0
# Name: 72, dtype: object
# year                                           2000
# movie                            Where the Heart Is
# rate                                            6.8
# votes                                         27563
# awards_wins                                       0
# Oscar_Best_Picture_nominated                      0
# Oscar_Best_Director_nominated                     0
# Oscar_Best_Actor_nominated                        0
# Oscar_Best_Actress_nominated                      0
# other_director_won                                0
# other_actor_won                                   0
# Name: 73, dtype: object
# year                                       2001
# movie                            Monsters, Inc.
# rate                                        8.1
# votes                                    614220
# awards_wins                                   1
# Oscar_Best_Picture_nominated                  0
# Oscar_Best_Director_nominated                 0
# Oscar_Best_Actor_nominated                    0
# Oscar_Best_Actress_nominated                  0
# other_director_won                            0
# other_actor_won                               0
# Name: 74, dtype: object
# year                                          2000
# movie                            Love & Basketball
# rate                                           7.2
# votes                                        14809
# awards_wins                                      0
# Oscar_Best_Picture_nominated                     0
# Oscar_Best_Director_nominated                    0
# Oscar_Best_Actor_nominated                       0
# Oscar_Best_Actress_nominated                     0
# other_director_won                               0
# other_actor_won                                  0
# Name: 75, dtype: object
# year                                    2000
# movie                            Coyote Ugly
# rate                                     5.6
# votes                                  92599
# awards_wins                                0
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# Oscar_Best_Actor_nominated                 0
# Oscar_Best_Actress_nominated               0
# other_director_won                         0
# other_actor_won                            0
# Name: 76, dtype: object
# year                                      2001
# movie                            Moulin Rouge!
# rate                                       7.6
# votes                                   229031
# awards_wins                                 24
# Oscar_Best_Picture_nominated                 1
# Oscar_Best_Director_nominated                0
# Oscar_Best_Actor_nominated                   0
# Oscar_Best_Actress_nominated                 1
# other_director_won                           1
# other_actor_won                              1
# Name: 77, dtype: object
# year                                     2000
# movie                            Men of Honor
# rate                                      7.2
# votes                                   91691
# awards_wins                                 0
# Oscar_Best_Picture_nominated                0
# Oscar_Best_Director_nominated               0
# Oscar_Best_Actor_nominated                  0
# Oscar_Best_Actress_nominated                0
# other_director_won                          0
# other_actor_won                             0
# Name: 78, dtype: object
# year                                   2000
# movie                            Sexy Beast
# rate                                    7.3
# votes                                 44469
# awards_wins                               3
# Oscar_Best_Picture_nominated              0
# Oscar_Best_Director_nominated             0
# Oscar_Best_Actor_nominated                0
# Oscar_Best_Actress_nominated              0
# other_director_won                        0
# other_actor_won                           0
# Name: 79, dtype: object
# year                                            2000
# movie                            You Can Count on Me
# rate                                             7.7
# votes                                          23102
# awards_wins                                        5
# Oscar_Best_Picture_nominated                       0
# Oscar_Best_Director_nominated                      0
# Oscar_Best_Actor_nominated                         0
# Oscar_Best_Actress_nominated                       1
# other_director_won                                 0
# other_actor_won                                    0
# Name: 80, dtype: object
# year                                    2000
# movie                            The Watcher
# rate                                     5.3
# votes                                  22568
# awards_wins                                0
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# Oscar_Best_Actor_nominated                 0
# Oscar_Best_Actress_nominated               0
# other_director_won                         0
# other_actor_won                            0
# Name: 81, dtype: object
# year                                    2000
# movie                            Bring It On
# rate                                     5.9
# votes                                  71924
# awards_wins                                0
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# ...
# movie                             Elle
# rate                               7.3
# votes                            21561
# awards_wins                          7
# Oscar_Best_Picture_nominated         0
# Oscar_Best_Director_nominated        0
# Oscar_Best_Actor_nominated           0
# Oscar_Best_Actress_nominated         1
# other_director_won                   0
# other_actor_won                      0
# Name: 1134, dtype: object
# year                                               2016
# movie                            Underworld: Blood Wars
# rate                                                6.4
# votes                                              9965
# awards_wins                                           0
# Oscar_Best_Picture_nominated                          0
# Oscar_Best_Director_nominated                         0
# Oscar_Best_Actor_nominated                            0
# Oscar_Best_Actress_nominated                          0
# other_director_won                                    0
# other_actor_won                                       0
# Name: 1135, dtype: object
# year                             2016
# movie                            Lion
# rate                                8
# votes                            6566
# awards_wins                         5
# Oscar_Best_Picture_nominated        1
# Oscar_Best_Director_nominated       0
# Oscar_Best_Actor_nominated          0
# Oscar_Best_Actress_nominated        0
# other_director_won                  0
# other_actor_won                     0
# Name: 1137, dtype: object
# year                                                     2016
# movie                            Rogue One: A Star Wars Story
# rate                                                      8.1
# votes                                                  227448
# awards_wins                                                 0
# Oscar_Best_Picture_nominated                                0
# Oscar_Best_Director_nominated                               0
# Oscar_Best_Actor_nominated                                  0
# Oscar_Best_Actress_nominated                                0
# other_director_won                                          0
# other_actor_won                                             0
# Name: 1138, dtype: object
# year                                   2016
# movie                            La La Land
# rate                                    8.7
# votes                                 78781
# awards_wins                              40
# Oscar_Best_Picture_nominated              1
# Oscar_Best_Director_nominated             1
# Oscar_Best_Actor_nominated                1
# Oscar_Best_Actress_nominated              1
# other_director_won                        6
# other_actor_won                           0
# Name: 1139, dtype: object
# year                                    2015
# movie                            Son of Saul
# rate                                     7.5
# votes                                  28106
# awards_wins                                9
# Oscar_Best_Picture_nominated               0
# Oscar_Best_Director_nominated              0
# Oscar_Best_Actor_nominated                 0
# Oscar_Best_Actress_nominated               0
# other_director_won                         1
# other_actor_won                            0
# Name: 1140, dtype: object
# year                              2015
# movie                            A War
# rate                               7.1
# votes                             5679
# awards_wins                          0
# Oscar_Best_Picture_nominated         0
# Oscar_Best_Director_nominated        0
# Oscar_Best_Actor_nominated           0
# Oscar_Best_Actress_nominated         0
# other_director_won                   0
# other_actor_won                      0
# Name: 1141, dtype: object
# year                                     2015
# movie                            Land of Mine
# rate                                      7.8
# votes                                    9002
# awards_wins                                 0
# Oscar_Best_Picture_nominated                0
# Oscar_Best_Director_nominated               0
# Oscar_Best_Actor_nominated                  0
# Oscar_Best_Actress_nominated                0
# other_director_won                          0
# other_actor_won                             0
# Name: 1142, dtype: object
# year                                2015
# movie                            Mustang
# rate                                 7.7
# votes                              21589
# awards_wins                            0
# Oscar_Best_Picture_nominated           0
# Oscar_Best_Director_nominated          0
# Oscar_Best_Actor_nominated             0
# Oscar_Best_Actress_nominated           0
# other_director_won                     0
# other_actor_won                        0
# Name: 1145, dtype: object
# year                                              2016
# movie                            Manchester by the Sea
# rate                                               8.4
# votes                                            17469
# awards_wins                                         18
# Oscar_Best_Picture_nominated                         1
# Oscar_Best_Director_nominated                        1
# Oscar_Best_Actor_nominated                           1
# Oscar_Best_Actress_nominated                         0
# other_director_won                                   0
# other_actor_won                                      6
# Name: 1146, dtype: object
# year                                   2015
# movie                            Green Room
# rate                                    7.1
# votes                                 51933
# awards_wins                               0
# Oscar_Best_Picture_nominated              0
# Oscar_Best_Director_nominated             0
# Oscar_Best_Actor_nominated                0
# Oscar_Best_Actress_nominated              0
# other_director_won                        0
# other_actor_won                           0
# Name: 1147, dtype: object
# year                                         2015
# movie                            A Man Called Ove
# rate                                          7.6
# votes                                       14782
# awards_wins                                     0
# Oscar_Best_Picture_nominated                    0
# Oscar_Best_Director_nominated                   0
# Oscar_Best_Actor_nominated                      0
# Oscar_Best_Actress_nominated                    0
# other_director_won                              0
# other_actor_won                                 0
# Name: 1148, dtype: object
# year                                                2016
# movie                            Florence Foster Jenkins
# rate                                                   7
# votes                                              24036
# awards_wins                                            3
# Oscar_Best_Picture_nominated                           0
# Oscar_Best_Director_nominated                          0
# Oscar_Best_Actor_nominated                             0
# Oscar_Best_Actress_nominated                           1
# other_director_won                                     0
# other_actor_won                                        0
# Name: 1149, dtype: object
# year                                 2016
# movie                            13 Hours
# rate                                  7.3
# votes                               69707
# awards_wins                             0
# Oscar_Best_Picture_nominated            0
# Oscar_Best_Director_nominated           0
# Oscar_Best_Actor_nominated              0
# Oscar_Best_Actress_nominated            0
# other_director_won                      0
# other_actor_won                         0
# Name: 1150, dtype: object
# year                              2015
# movie                            Tanna
# rate                               7.1
# votes                              997
# awards_wins                          0
# Oscar_Best_Picture_nominated         0
# Oscar_Best_Director_nominated        0
# Oscar_Best_Actor_nominated           0
# Oscar_Best_Actress_nominated         0
# other_director_won                   0
# other_actor_won                      0
# Name: 1152, dtype: object
# year                                  2015
# movie                            The Witch
# rate                                   6.7
# votes                                89793
# awards_wins                              2
# Oscar_Best_Picture_nominated             0
# Oscar_Best_Director_nominated            0
# Oscar_Best_Actor_nominated               0
# Oscar_Best_Actress_nominated             0
# other_director_won                       0
# other_actor_won                          0
# Name: 1153, dtype: object
# year                                               2015
# movie                            Embrace of the Serpent
# rate                                                7.9
# votes                                             11588
# awards_wins                                           0
# Oscar_Best_Picture_nominated                          0
# Oscar_Best_Director_nominated                         0
# Oscar_Best_Actor_nominated                            0
# Oscar_Best_Actress_nominated                          0
# other_director_won                                    0
# other_actor_won                                       0
# Name: 1154, dtype: object
# year                                                 2016
# movie                            Kubo and the Two Strings
# rate                                                  7.9
# votes                                               56049
# awards_wins                                             3
# Oscar_Best_Picture_nominated                            0
# Oscar_Best_Director_nominated                           0
# Oscar_Best_Actor_nominated                              0
# Oscar_Best_Actress_nominated                            0
# other_director_won                                      0
# other_actor_won                                         0
# Name: 1155, dtype: object
# year                                           2016
# movie                            20th Century Women
# rate                                            7.7
# votes                                          3020
# awards_wins                                       0
# Oscar_Best_Picture_nominated                      0
# Oscar_Best_Director_nominated                     0
# Oscar_Best_Actor_nominated                        0
# Oscar_Best_Actress_nominated                      0
# other_director_won                                0
# other_actor_won                                   0
# Name: 1156, dtype: object
# year                                 2016
# movie                            Why Him?
# rate                                  6.6
# votes                               10274
# awards_wins                             0
# Oscar_Best_Picture_nominated            0
# Oscar_Best_Director_nominated           0
# Oscar_Best_Actor_nominated              0
# Oscar_Best_Actress_nominated            0
# other_director_won                      0
# other_actor_won                         0
# Name: 1157, dtype: object
# year                                                    2016
# movie                            The Girl with All the Gifts
# rate                                                     6.9
# votes                                                   8335
# awards_wins                                                1
# Oscar_Best_Picture_nominated                               0
# Oscar_Best_Director_nominated                              0
# Oscar_Best_Actor_nominated                                 0
# Oscar_Best_Actress_nominated                               0
# other_director_won                                         0
# other_actor_won                                            0
# Name: 1158, dtype: object
# year                                          2016
# movie                            Nocturnal Animals
# rate                                           7.7
# votes                                        46191
# awards_wins                                      2
# Oscar_Best_Picture_nominated                     0
# Oscar_Best_Director_nominated                    0
# Oscar_Best_Actor_nominated                       0
# Oscar_Best_Actress_nominated                     0
# other_director_won                               0
# other_actor_won                                  0
# Name: 1159, dtype: object
# year                                     2016
# movie                            Patriots Day
# rate                                      7.6
# votes                                    7375
# awards_wins                                 0
# Oscar_Best_Picture_nominated                0
# Oscar_Best_Director_nominated               0
# Oscar_Best_Actor_nominated                  0
# Oscar_Best_Actress_nominated                0
# other_director_won                          0
# other_actor_won                             0
# Name: 1161, dtype: object
# year                               2016
# movie                            Loving
# rate                                7.1
# votes                              9367
# awards_wins                           0
# Oscar_Best_Picture_nominated          0
# Oscar_Best_Director_nominated         0
# Oscar_Best_Actor_nominated            0
# Oscar_Best_Actress_nominated          1
# other_director_won                    0
# other_actor_won                       0
# Name: 1162, dtype: object
# year                                          2016
# movie                            Collateral Beauty
# rate                                           6.6
# votes                                        11436
# awards_wins                                      1
# Oscar_Best_Picture_nominated                     0
# Oscar_Best_Director_nominated                    0
# Oscar_Best_Actor_nominated                       0
# Oscar_Best_Actress_nominated                     0
# other_director_won                               0
# other_actor_won                                  0
# Name: 1163, dtype: object
# year                                       2016
# movie                            Hidden Figures
# rate                                        7.9
# votes                                      9938
# awards_wins                                   3
# Oscar_Best_Picture_nominated                  1
# Oscar_Best_Director_nominated                 0
# Oscar_Best_Actor_nominated                    0
# Oscar_Best_Actress_nominated                  0
# other_director_won                            0
# other_actor_won                               0
# Name: 1164, dtype: object
# year                              2016
# movie                            Split
# rate                               7.6
# votes                             2416
# awards_wins                          0
# Oscar_Best_Picture_nominated         0
# Oscar_Best_Director_nominated        0
# Oscar_Best_Actor_nominated           0
# Oscar_Best_Actress_nominated         0
# other_director_won                   0
# other_actor_won                      0
# Name: 1166, dtype: object
# year                                  2016
# movie                            Moonlight
# rate                                   8.5
# votes                                14324
# awards_wins                             24
# Oscar_Best_Picture_nominated             1
# Oscar_Best_Director_nominated            1
# Oscar_Best_Actor_nominated               0
# Oscar_Best_Actress_nominated             0
# other_director_won                       4
# other_actor_won                          0
# Name: 1167, dtype: object
# year                                                   2016
# movie                            Jim: The James Foley Story
# rate                                                    7.8
# votes                                                   631
# awards_wins                                               0
# Oscar_Best_Picture_nominated                              0
# Oscar_Best_Director_nominated                             0
# Oscar_Best_Actor_nominated                                0
# Oscar_Best_Actress_nominated                              0
# other_director_won                                        0
# other_actor_won                                           0
# Name: 1171, dtype: object

# %%
 # converting numpy array to dataframe
X_train=pd.DataFrame(X_train)
Y_train=pd.DataFrame(Y_train)
X_test=pd.DataFrame(X_test)
Y_test=pd.DataFrame(Y_test)

# %%
movie=X_test['movie']

# %%
X_train=X_train.drop(['movie'],axis=1)
                                                            # dropping movie column to do ananlysis since Oscar winnings is least
                                                            # likely to depend on movie names 
X_test=X_test.drop(['movie'],axis=1)

# %%
X_train=(X_train-X_train.min())/(X_train.max()-X_train.min())
Y_train=(Y_train-Y_train.min())/(Y_train.max()-Y_train.min())     #normalising the entire test train
X_test=(X_test-X_test.min())/(X_test.max()-X_test.min())
Y_test=(Y_test-Y_test.min())/(Y_test.max()-Y_test.min())

# %%
X_train=X_train.drop(['year'],axis=1)
X_test=X_test.drop(['year'],axis=1)                           #dropping year column

# %%
regr=LinearRegression()                                   #training the linear regression model

# %%
regr.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred=regr.predict(X_test)

# %%
regr.score(X_test,Y_test)
# Out:
# 0.6075654716215941

# %%
df_norm=pd.DataFrame(pred)
df_norm=(df_norm-df_norm.min())/(df_norm.max()-df_norm.min())

# %%
indexList=df_norm.sort_values(by=[0],ascending=False).head(5).index.to_list()
sort=df_norm.sort_values(by=[0],ascending=False).head(5)

# %%
movie=pd.DataFrame(movie.values)
movie
# Out:
#                                             0
# 0                        The Greatest Showman
# 1                           Blade Runner 2049
# 2                                        Coco
# 3                                    Mudbound
# 4                    Star Wars: The Last Jedi
# 5                                      Wonder
# 6                        Beauty and the Beast
# 7                                       Logan
# 8              War for the Planet of the Apes
# 9                         The Disaster Artist
# 10                         Kong: Skull Island
# 11                                Baby Driver
# 12             Guardians of the Galaxy Vol. 2
# 13                               Molly's Game
# 14                               Darkest Hour
# 15                                  Lady Bird
# 16                                    Dunkirk
# 17  Three Billboards Outside Ebbing, Missouri
# 18                                    Get Out
# 19                 All the Money in the World
# 20                                   Marshall
# 21                               The Big Sick
# 22                                   I, Tonya
# 23                         The Shape of Water
# 24                        The Florida Project
# 25                       Call Me by Your Name
# 26                             Phantom Thread
# 27                           Victoria & Abdul
# 28                      Roman J. Israel, Esq.
# 29                                   The Post

# %%
 # converting  top 5 of these predictions to 
# probabilty using softmax and equating them to respective movie names
deno=0
for i in indexList:
    deno+=np.exp(sort[0][i])
for i in indexList:
    print(movie[0][i],np.exp(sort[0][i])/deno,sep=':')
# Out:
# The Shape of Water:0.34319698494685885
# Dunkirk:0.18056745715088682
# The Florida Project:0.16096745252430664
# Call Me by Your Name:0.1585555003706696
# Darkest Hour:0.15671260500727816

# %%
df_norm.sort_values(by=[0],ascending=False).head(5)
# Out:
#            0
# 23  1.000000
# 16  0.357800
# 24  0.242898
# 25  0.227800
# 14  0.216109

# %%
# following snippet is used to get importance of each attribute with the help of linear regression 
# initially only output labels will be dropped from the dataset

from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot

# define the model
model = LinearRegression()
# fit the model
model.fit(X_train, Y_train)
# get importance
importance = model.coef_
# summarize feature importance
a=importance[0]
a=sorted(a,reverse=True)

b=importance[0]
c=[col for col in X_train.columns]
dic=dict()
for i,v in enumerate(b):
    if(v>=0):
        dic[c[i]]=v
a={k:v for k,v in sorted(dic.items(),reverse=True,key= lambda item:item[1])}

# plot feature importance
pyplot.bar([x for x in range(len(importance[0]))], importance[0])
pyplot.show()

# %%
a  #  imporance of attributes(only those whose importance >0)
# Out:
# {'other_director_won': 0.8808287230377743,
#  'Oscar_Best_Picture_won': 0.3559824057188191,
#  'awards_wins': 0.10419148228784396,
#  'votes': 0.06604997931424735,
#  'Oscar_Best_Director_nominated': 0.06483189191036966,
#  'other_actor_nominated': 0.05317229458001684,
#  'Oscar_Best_Picture_nominated': 0.021267159414458437,
#  'Oscar_Best_Actor_nominated': 0.020694553402143274,
#  'other_actress_nominated': 0.019278314336067855,
#  'Oscar_Best_Actress_nominated': 0.019267325344424033,
#  'rate': 0.01787202893541793,
#  'other_actor_won': 0.0107968137273581,
#  'gross': 0.006936953537138209}

# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns                     #scatter plot with the highest important attribute
matplotlib.style.use('ggplot')
x=X_train['other_director_won']
y=Y_train[0]
plt.scatter(x,y)
plt.show()

# %%
corrDf=pd.DataFrame()                                      #initialising correlation dataframe
corrDf['other_director_won']=X_train['other_director_won']
corrDf['awards_wins']=X_train['awards_wins']
corrDf[ 'votes']=X_train[ 'votes']
corrDf['other_actor_won']=X_train['other_actor_won']
corrDf['Oscar_Best_Director_nominated']=X_train['Oscar_Best_Director_nominated']
corrDf['Oscar_Best_Actress_nominated']= X_train['Oscar_Best_Actress_nominated']
corrDf['Oscar_Best_Actor_nominated']= X_train['Oscar_Best_Actor_nominated']
corrDf['Oscar_Best_Picture_nominated']= X_train['Oscar_Best_Picture_nominated']
corrDf['Oscar_Best_Director_won']=Y_train[0]
sns.heatmap(corrDf.corr());                                                     #heatmaps of correrelation
